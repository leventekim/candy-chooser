# %% [markdown]
# The aim of this notebook is to perform exploratory analysis on the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading in data
data = pd.read_csv("candy-data.csv")

# %%
# get shape of dataframe plus file size
data.info()
# Out:
# Shape: (85, 13)
# Size of file: 0.01 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   competitorname    85 non-null     object
#  1   chocolate         85 non-null     int64
#  2   fruity            85 non-null     int64
#  3   caramel           85 non-null     int64
#  4   peanutyalmondy    85 non-null     int64
#  5   nougat            85 non-null     int64
#  6   crispedricewafer  85 non-null     int64
#  7   hard              85 non-null     int64
#  8   bar               85 non-null     int64
#  9   pluribus          85 non-null     int64
#  10  sugarpercent      85 non-null     float64
#  11  pricepercent      85 non-null     float64
#  12  winpercent        85 non-null     float64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 8.8+ KB

# %%
# checking null values per column
data.isnull().sum()
# Out:
# competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %%
# check summary statistics of columns
print(data.describe())
# Out:
#        chocolate     fruity    caramel  peanutyalmondy     nougat  \
# count  85.000000  85.000000  85.000000       85.000000  85.000000
# mean    0.435294   0.447059   0.164706        0.164706   0.082353
# std     0.498738   0.500140   0.373116        0.373116   0.276533
# min     0.000000   0.000000   0.000000        0.000000   0.000000
# 25%     0.000000   0.000000   0.000000        0.000000   0.000000
# 50%     0.000000   0.000000   0.000000        0.000000   0.000000
# 75%     1.000000   1.000000   0.000000        0.000000   0.000000
# max     1.000000   1.000000   1.000000        1.000000   1.000000
#
#        crispedricewafer       hard        bar   pluribus  sugarpercent  \
# count         85.000000  85.000000  85.000000  85.000000     85.000000
# mean           0.082353   0.176471   0.247059   0.517647      0.478647
# std            0.276533   0.383482   0.433861   0.502654      0.282778
# min            0.000000   0.000000   0.000000   0.000000      0.011000
# ...

# %%
# visualize the relationship between the target and non-binary features
non_binary_cols = data.select_dtypes(include="float64").columns.tolist()
sns.pairplot(data, y_vars = non_binary_cols)
plt.show()

# %%
# plotting histogram of winpercent for presentation
sns.displot(data["winpercent"], kind="hist", color="#FFF000")
plt.title("The distribution of winpercent is right-skewed.")
plt.xlabel("Win percent (% of matchups)")
plt.show()

# %%
g = sns.catplot(data=data,x="winpercent",
            row="crispedricewafer",col="hard",
            kind="box",color="#0050AA")
g.set_axis_labels("Win pct. (% of matchups)", "")
g.figure.suptitle("Soft candies with cookie component have the highest median win percentage.", y=1.05)
plt.show()
