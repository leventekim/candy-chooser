# %%
import pandas as pd

# %%
data = pd.read_csv("candy-data.csv")
data_cleaned = data.copy()

# transform winpercent to [0,1]
data_cleaned["winpercent"] = data_cleaned["winpercent"]/100

# save the data
data_cleaned.to_csv("candy-data-cleaned.csv", index=False)
